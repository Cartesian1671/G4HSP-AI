# %%
from google.colab import drive
drive.mount('/content/gdrive')

# Now you can access your Google Drive as a local file system
with open('/content/CollatedText.txt', 'r') as file:
    corpus = [line.strip() for line in file]
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# -*- coding: utf-8 -*-
import os
os.environ["LC_ALL"] = "en_US.utf8"
os.environ["LANG"] = "en_US.utf8"

# %%
# Install necessary packages
# !pip install bertopic==0.14.1
# !pip install -U pyldavis==3.4.1
# !pip install numpy==1.23.5
# !pip install --upgrade gensim nltk numpy
# !pip install --upgrade gensim
# !pip install --upgrade nltk
# !pip install sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 35.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 86.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 51.2 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall numba -y 
# !pip install numba
# Out:
# Found existing installation: numba 0.56.4
# Uninstalling numba-0.56.4:
#   Successfully uninstalled numba-0.56.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 9.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
# ...

# %%
# !pip install pyLDAvis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
def prepare_corpus(doc_clean):
    """
    This function prepares the corpus by creating a dictionary and document-term matrix.
    Input: 
    - doc_clean: A list of tokenized documents
    Return: 
    - dictionary: A mapping from word IDs to words
    - doc_term_matrix: A list of bag-of-word vectors representing each document
    """
    # Creating the term dictionary of our corpus, where every unique term is assigned an index. 
    dictionary = gensim.corpora.Dictionary(doc_clean)

    # Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
    doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]
    
    return dictionary, doc_term_matrix

# %%
import nltk
nltk.download('stopwords')  # add this line to download the stopwords
nltk.download('wordnet')  # this downloads the wordnet
import requests
import re
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
from gensim import corpora
from gensim.models import LsiModel, LdaModel
from nltk.stem import WordNetLemmatizer
from gensim.models.coherencemodel import CoherenceModel

# Load the articles as a list
with open('/content/CollatedText.txt', 'r', encoding="utf-8") as a:
    docs = [doc.strip() for doc in a.readlines()]

def preprocess_data(doc_set):
    tokenizer = RegexpTokenizer(r'\w+')
    en_stop = set(stopwords.words('english'))
    lemmatizer = WordNetLemmatizer()   # Use NLTK's WordNetLemmatizer
    texts = []

    for i in doc_set:
        raw = i.lower()
        # remove references like [3,4] and (Fig. 1)
        raw = re.sub(r'\[[^\]]*\]', '', raw)
        raw = re.sub(r'\(Fig\. .*?\)', '', raw)
        # split into tokens
        tokens = tokenizer.tokenize(raw)
        # remove stopwords
        stopped_tokens = [i for i in tokens if not i in en_stop]
        # lemmatize tokens
        lemmatized_tokens = [lemmatizer.lemmatize(i) for i in stopped_tokens]
        texts.append(lemmatized_tokens)

    return texts

def prepare_corpus(doc_clean):
    dictionary = corpora.Dictionary(doc_clean)
    doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]
    return dictionary, doc_term_matrix

clean_docs = preprocess_data(docs)
dictionary, doc_term_matrix = prepare_corpus(clean_docs)

# LSI Model
lsi_model = LsiModel(doc_term_matrix, num_topics=20, id2word = dictionary)
print("LSI Model:")
for idx, topic in lsi_model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))

# LDA Model
lda_model = LdaModel(doc_term_matrix, num_topics=20, id2word = dictionary)
print("LDA Model:")
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# WARNING:gensim.models.ldamodel:too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# LSI Model:
# Topic: 0 Word: 0.660*"virus" + 0.317*"group" + 0.254*"family" + 0.240*"acid" + 0.240*"type" + 0.229*"symmetry" + 0.225*"belongs" + 0.113*"ivof" + 0.113*"ssnucleic" + 0.113*"virushas"
# Topic: 1 Word: -0.410*"g" + -0.265*"protein" + -0.262*"sg" + -0.222*"g3bp1" + -0.211*"viral" + -0.207*"virus" + -0.205*"quadruplex" + -0.186*"rna" + -0.185*"cell" + -0.147*"structure"
# Topic: 2 Word: 0.503*"g" + -0.372*"sg" + 0.298*"quadruplex" + -0.275*"protein" + -0.268*"g3bp1" + -0.236*"viral" + 0.168*"structure" + -0.138*"mrna" + 0.137*"dna" + -0.135*"infection"
# ...

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda_model, doc_term_matrix, dictionary)
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el94351398835099700003693728938" style="background-color:white;"></div>
# <script type="text/javascript">
#
# ...

# %%
from google.colab import drive
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# mount the drive
drive.mount('/content/gdrive')

# open your corpus file from drive and load the content
with open('/content/CollatedText.txt', 'r') as file:
    corpus = [line.strip() for line in file]

# This vectorizer will convert our documents into a matrix of TF-IDF features
vectorizer = TfidfVectorizer()

# Vectorize our documents
tfidf_matrix = vectorizer.fit_transform(corpus)

def search(query):
    # Vectorize the query to the same feature space as our documents
    query_vec = vectorizer.transform([query])

    # Compute the cosine similarity between the query and all documents
    sims = cosine_similarity(query_vec, tfidf_matrix).flatten()

    # Sort the document indices by their similarity score
    ranking = sims.argsort()[::-1]

    # Print out the ranking
    for i in range(len(ranking)):
        print(f"Document #{ranking[i]}: {corpus[ranking[i]]} (score: {sims[ranking[i]]})")

# We try it out
search("G4")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# Document #5: ‘In general, G4 ligands showed promising antiviral activity, with G4-mediated mechanisms of action both at the genome and transcript level.’ (score: 0.4870952927086342)
# Document #17: ‘However, mapping of G4s in chromatin by G4 ChIP-sequencing with an anti-G4 antibody (13) or foot printing (14) retrieved only about 10000 G4s in highly transcribed regulatory nucleosome-depleted chromatin regions.’ (score: 0.32413775388010746)
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# This vectorizer will convert our documents into a matrix of TF-IDF features
vectorizer = TfidfVectorizer()

# Vectorize our documents
tfidf_matrix = vectorizer.fit_transform(corpus)  # Change 'documents' to 'corpus'

def search(query):
    # Vectorize the query to the same feature space as our documents
    query_vec = vectorizer.transform([query])

    # Compute the cosine similarity between the query and all documents
    sims = cosine_similarity(query_vec, tfidf_matrix).flatten()

    # Sort the document indices by their similarity score
    ranking = sims.argsort()[::-1]

    # Print out the ranking
    for i in range(len(ranking)):
        print(f"Document #{ranking[i]}: {corpus[ranking[i]]} (score: {sims[ranking[i]]})")  # Change 'documents' to 'corpus'

# Let's try it out
search("HIV-1")
# Out:
# Document #643: Reoviridaevirus family, such as the Reovirus, rotavirushas a NakedcapsidIcosahedralcapsid symmetry, dsnucleic acid type and belongs to the Group IIIof viruses. Picornaviridaevirus family, such as the Enterovirus, rhinovirus, hepatovirus, cardiovirus, aphthovirus, poliovirus, parechovirus, erbovirus, kobuvirus, teschovirus, coxsackiehas a NakedcapsidIcosahedralcapsid symmetry, ssnucleic acid type and belongs to the Group IVof viruses. Caliciviridaevirus family, such as the Norwalk virushas a NakedcapsidIcosahedralcapsid symmetry, ssnucleic acid type and belongs to the Group IVof viruses. Togaviridaevirus family, such as the Eastern equine encephalitishas a EnvelopedcapsidIcosahedralcapsid symmetry, ssnucleic acid type and belongs to the Group IVof viruses. Arenaviridaevirus family, such as the Lymphocytic choriomeningitis virus, Lassa feverhas a EnvelopedcapsidComplexcapsid symmetry, ss(−)nucleic acid type and belongs to the Group Vof viruses. Flaviviridaevirus family, 
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# This vectorizer will convert our documents into a matrix of TF-IDF features
vectorizer = TfidfVectorizer()

# Vectorize our documents
tfidf_matrix = vectorizer.fit_transform(corpus)  # Change 'documents' to 'corpus'

def search(query):
    # Vectorize the query to the same feature space as our documents
    query_vec = vectorizer.transform([query])

    # Compute the cosine similarity between the query and all documents
    sims = cosine_similarity(query_vec, tfidf_matrix).flatten()

    # Sort the document indices by their similarity score
    ranking = sims.argsort()[::-1]

    # Print out the ranking
    for i in range(len(ranking)):
        print(f"Document #{ranking[i]}: {corpus[ranking[i]]} (score: {sims[ranking[i]]})")  # Change 'documents' to 'corpus'

# Let's try it out
search("HSP90")
# Out:
# Document #867:  (score: 0.0)
# Document #284: ‘G3BP1 ADP-ribosylation, a key driver of SG assembly, is reduced in cells infected by wild-type CHIKV, but not a mutant virus that lacks hydrolase activity.’ (score: 0.0)
# Document #295: ‘In addition, knockdown of MNV-induced G3BP1 interactors reduces MNV replication, suggesting that the G3BP1 interactome consists of host factors that are required for efficient viral replication complex formation [84,107].’ (score: 0.0)
# Document #294: ‘Consistently, genetic depletion of G3BP1 severely affects viral replication and translation.’ (score: 0.0)
# Document #293: ‘The proteome of G3BP1 granules contains several proteins that are present in viral replication complexes, suggesting a pro-viral role of G3BP1 during MNV infection.’ (score: 0.0)
# Document #292: remodels G3BP1 interactome in infected cells and induces cytoplasmic G3BP1 granules during infection that are distinct from SGs.’ (score: 0.0)
# Document #291: ‘MNV (score: 0.0)
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# This vectorizer will convert our documents into a matrix of TF-IDF features
vectorizer = TfidfVectorizer()

# Vectorize our documents
tfidf_matrix = vectorizer.fit_transform(corpus)  # Change 'documents' to 'corpus'

def search(query):
    # Vectorize the query to the same feature space as our documents
    query_vec = vectorizer.transform([query])

    # Compute the cosine similarity between the query and all documents
    sims = cosine_similarity(query_vec, tfidf_matrix).flatten()

    # Sort the document indices by their similarity score
    ranking = sims.argsort()[::-1]

    # Print out the ranking
    for i in range(len(ranking)):
        print(f"Document #{ranking[i]}: {corpus[ranking[i]]} (score: {sims[ranking[i]]})")  # Change 'documents' to 'corpus'

# Let's try it out
search("HSP90")
